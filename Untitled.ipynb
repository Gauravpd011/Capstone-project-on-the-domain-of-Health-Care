# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel("Sample_data_depression.xlsx")
df.head()
# Out:
#    addprev  addscev  adlosev  addpdisc  addplsin  addslsin  adlsi2wk  \
# 0       99       99       99        99        99        99        99
# 1        2        2        2        99        99        99        99
# 2        1       99       99         1         1        99        99
# 3       99       99       99        99        99        99        99
# 4        2        2        2        99        99        99        99
#
#    addpr2wk  adwrhrs  adwrdst  ...  adothmhp  adnurse  adrelig  adherbal  \
# 0        99       99       99  ...        99       99       99        99
# 1        99       99       99  ...        99       99       99        99
# 2         2       99       99  ...        99       99       99        99
# 3        99       99       99  ...        99       99       99        99
# 4        99       99       99  ...        99       99       99        99
#
#    adothhlp  adtmtnow  adrx12mo  adrxnow  adrxhlp  adtmthlp
# 0        99        99        99       99       99        99
# 1        99        99        99       99       99        99
# 2        99        99        99       99       99        99
# 3        99        99        99       99       99        99
# 4        99        99        99       99       99        99
#
# [5 rows x 83 columns]

# %%
df.shape
# Out:
# (149, 83)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 83 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   addprev   149 non-null    int64
#  1   addscev   149 non-null    int64
#  2   adlosev   149 non-null    int64
#  3   addpdisc  149 non-null    int64
#  4   addplsin  149 non-null    int64
#  5   addslsin  149 non-null    int64
#  6   adlsi2wk  149 non-null    int64
#  7   addpr2wk  149 non-null    int64
#  8   adwrhrs   149 non-null    int64
#  9   adwrdst   149 non-null    int64
#  10  adwrchr   149 non-null    int64
#  11  adwrimp   149 non-null    int64
#  12  addpprob  149 non-null    int64
#  13  adwrprob  149 non-null    int64
#  14  adwrage   149 non-null    int64
#  15  adwrdepr  149 non-null    int64
#  16  adwrdisc  149 non-null    int64
#  17  adwrlsin  149 non-null    int64
#  18  adwrplsr  149 non-null    int64
#  19  adwreles  149 non-null    int64
#  20  adwremor  149 non-null    int64
#  21  adwrgain  149 non-null    int64
#  22  adwrgrow  149 non-null    int64
#  23  adwrpreg  149 non-null    int64
#  24  adwrgnl2  149 non-null    int64
#  25  adwrlose  149 non-null    int64
#  26  adwrdiet  149 non-null    int64
#  27  adwrlsl2  149 non-null    int64
#  28  adwrslep  149 non-null    int64
#  29  adwrsmor  149 non-null    int64
#  30  adwrenrg  149 non-null    int64
#  31  adwrslow  149 non-null    int64
#  32  adwrslno  149 non-null    int64
#  33  adwrjitt  149 non-null    int64
#  34  adwrjino  149 non-null    int64
#  35  adwrthot  149 non-null    int64
#  36  adwrconc  149 non-null    int64
#  37  adwrdcsn  149 non-null    int64
#  38  adwrnogd  149 non-null    int64
#  39  adwrwrth  149 non-null    int64
#  40  adwrdlot  149 non-null    int64
#  41  adwrdbtr  149 non-null    int64
#  42  adwrsthk  149 non-null    int64
#  43  adwrspln  149 non-null    int64
#  44  adwrsatp  149 non-null    int64
#  45  ad_mdea1  149 non-null    int64
#  46  ad_mdea2  149 non-null    int64
#  47  ad_mdea3  149 non-null    int64
#  48  ad_mdea4  149 non-null    int64
#  49  ad_mdea5  149 non-null    int64
#  50  ad_mdea6  149 non-null    int64
#  51  ad_mdea7  149 non-null    int64
#  52  ad_mdea8  149 non-null    int64
#  53  ad_mdea9  149 non-null    int64
#  54  adsmmdea  149 non-null    int64
#  55  adpbintf  149 non-null    int64
#  56  adpbdlya  149 non-null    int64
#  57  adpbrmbr  149 non-null    int64
#  58  adpbage   149 non-null    int64
#  59  adpbnum   149 non-null    int64
#  60  adpb2wk   149 non-null    int64
#  61  adpshmgt  149 non-null    int64
#  62  adpswork  149 non-null    int64
#  63  adpsrels  149 non-null    int64
#  64  adpssoc   149 non-null    int64
#  65  adpsdays  149 non-null    int64
#  66  adseedoc  149 non-null    int64
#  67  adfamdoc  149 non-null    int64
#  68  adothdoc  149 non-null    int64
#  69  adpsych   149 non-null    int64
#  70  adpsymd   149 non-null    int64
#  71  adsocwrk  149 non-null    int64
#  72  adcouns   149 non-null    int64
#  73  adothmhp  149 non-null    int64
#  74  adnurse   149 non-null    int64
#  75  adrelig   149 non-null    int64
#  76  adherbal  149 non-null    int64
#  77  adothhlp  149 non-null    int64
#  78  adtmtnow  149 non-null    int64
#  79  adrx12mo  149 non-null    int64
#  80  adrxnow   149 non-null    int64
#  81  adrxhlp   149 non-null    int64
#  82  adtmthlp  149 non-null    int64
# dtypes: int64(83)
# memory usage: 96.7 KB

# %%
df["adtmthlp"]
# Out:
# 0      99
# 1      99
# 2      99
# 3      99
# 4      99
#        ..
# 144    99
# 145    99
# 146    99
# 147    99
# 148     4
# Name: adtmthlp, Length: 149, dtype: int64

# %%
cols=["ADDPREV1","ADDPDISC1","ADDPLSIN1","ADWRHRS1","ADWRDST1","ADWRCHR1","ADWRAGE1","ADWRDEPR1","ADWRDISC1","ADWRLSIN1","ADWRPLSR1","ADWRELES1","ADWREMOR1","ADWRGAIN1","ADWRGROW1","ADWRLOSE1","ADWRDIET1","ADWRSLEP1"]

# %%
# Because our dataset is large, we will read our data in chunks. Each chunk is stored in chunk_list
chunk_list = []

# Read the csv we exported from our R script into a pandas dataframe
for chunk in pd.read_csv("NSDUH_2015-2019.csv", index_col=False, usecols=cols, chunksize=1000):
    chunk_list.append(chunk)

# Concatenate all chunks, then delete our chunk_list to preserve memory
df = pd.concat(chunk_list, axis=0)
del chunk_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-365218713150> in <module>
#       3
#       4 # Read the csv we exported from our R script into a pandas dataframe
# ----> 5 for chunk in pd.read_csv("NSDUH_2015-2019.csv", index_col=False, usecols=cols, chunksize=1000):
#       6     chunk_list.append(chunk)
#       7
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1947                 self.orig_names
#    1948             ):
# -> 1949                 _validate_usecols_names(usecols, self.orig_names)
#    1950
#    1951             if len(self.names) > len(usecols):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _validate_usecols_names(usecols, names)
#    1160     missing = [c for c in usecols if c not in names]
#    1161     if len(missing) > 0:
# -> 1162         raise ValueError(
#    1163             f"Usecols do not match columns, columns expected but not found: {missing}"
#    1164         )
#
# ValueError: Usecols do not match columns, columns expected but not found: ['ADWRHRS1', 'ADWRCHR1', 'ADDPLSIN1', 'ADWRDST1', 'ADDPREV1', 'ADDPDISC1']
